# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_csv('country_vaccinations.csv')

# %%
df['people_fully_vaccinated'] = df['people_fully_vaccinated'].fillna(0)

# %%
df.loc[(df["country"]=="Wales")|(df["country"]=="Scotland")]
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 5063  Scotland      NaN  2020-12-13             19009.0            19009.0
# 5064  Scotland      NaN  2020-12-14                 NaN                NaN
# 5065  Scotland      NaN  2020-12-15                 NaN                NaN
# 5066  Scotland      NaN  2020-12-16                 NaN                NaN
# 5067  Scotland      NaN  2020-12-17                 NaN                NaN
# ...        ...      ...         ...                 ...                ...
# 6295     Wales      NaN  2021-03-09           1225604.0          1019210.0
# 6296     Wales      NaN  2021-03-10           1256043.0          1034141.0
# 6297     Wales      NaN  2021-03-11           1294144.0          1056787.0
# 6298     Wales      NaN  2021-03-12           1334355.0          1084329.0
# 6299     Wales      NaN  2021-03-13           1370896.0          1113498.0
#
# ...

# %%
df.loc[(df["country"]=="Wales")|(df["country"]=="Scotland")] = df.loc[(df["country"]=="Wales")|(df["country"]=="Scotland")].fillna('GBR')

# %%
df.loc[(df["country"]=="Wales")|(df["country"]=="Scotland")]
# Out:
#        country iso_code        date total_vaccinations people_vaccinated  \
# 5063  Scotland      GBR  2020-12-13            19009.0           19009.0
# 5064  Scotland      GBR  2020-12-14                GBR               GBR
# 5065  Scotland      GBR  2020-12-15                GBR               GBR
# 5066  Scotland      GBR  2020-12-16                GBR               GBR
# 5067  Scotland      GBR  2020-12-17                GBR               GBR
# ...        ...      ...         ...                ...               ...
# 6295     Wales      GBR  2021-03-09          1225604.0         1019210.0
# 6296     Wales      GBR  2021-03-10          1256043.0         1034141.0
# 6297     Wales      GBR  2021-03-11          1294144.0         1056787.0
# 6298     Wales      GBR  2021-03-12          1334355.0         1084329.0
# 6299     Wales      GBR  2021-03-13          1370896.0         1113498.0
#
#       people_fully_vaccinated daily_vaccinations_raw daily_vaccinations  \
# ...

# %%
wales = max(df.loc[(df["country"]=="Wales")]['people_fully_vaccinated'].values)
scotland = max(df.loc[(df["country"]=="Scotland")]['people_fully_vaccinated'].values)

# %%
scotland
# Out:
# 160038.0

# %%
countries = df['iso_code'].value_counts().keys().values
totVac=[]

# %%
countries
# Out:
# array(['GBR', 'CAN', 'RUS', 'ISR', 'USA', 'BHR', 'MEX', 'CHL', 'QAT',
#        'CRI', 'ITA', 'CZE', 'LTU', 'PRT', 'EST', 'AUT', 'HUN', 'CYM',
#        'SVN', 'FRA', 'DNK', 'GRC', 'ARG', 'BEL', 'DEU', 'POL', 'SWE',
#        'CHN', 'BGR', 'ROU', 'NOR', 'FIN', 'HRV', 'OMN', 'LVA', 'ISL',
#        'LUX', 'KWT', 'IRL', 'SVK', 'ARE', 'SAU', 'ESP', 'SRB', 'GIB',
#        'ALB', 'SYC', 'IDN', 'TUR', 'CYP', 'BMU', 'IND', 'BRA', 'SGP',
#        'AZE', 'MLT', 'PAN', 'IMN', 'BLR', 'ECU', 'NLD', 'GGY', 'BGD',
#        'LKA', 'BOL', 'CHE', 'MAR', 'AND', 'JOR', 'JEY', 'FRO', 'MDV',
#        'KHM', 'GRL', 'MAC', 'PER', 'LIE', 'TCA', 'RWA', 'AUS', 'LBN',
#        'NPL', 'ZAF', 'BRB', 'COL', 'SLV', 'ZWE', 'DOM', 'KAZ', 'MUS',
#        'JPN', 'AIA', 'MNE', 'DZA', 'HKG', 'PRY', 'MNG', 'NZL', 'SEN',
#        'PAK', 'MCO', 'DMA', 'UKR', 'MYS', 'KOR', 'LCA', 'GTM', 'MSR',
#        'VEN', 'GRD', 'FLK', 'URY', 'THA', 'SMR', 'CIV', 'BLZ', 'GUY',
# ...

# %%
for c in countries:
    if c=='GBR':
        val = max(df.loc[(df['iso_code']==c)]['people_fully_vaccinated'].values) +wales +scotland
        totVac.append({"code3":c, "z":val})
    else:
        val = max(df.loc[(df['iso_code']==c)]['people_fully_vaccinated'].values)
        totVac.append({"code3":c, "z":val})
# Out:
# 1584909.0

# %%
totVac
# Out:
# [{'code3': 'GBR', 'z': 2002345.0},
#  {'code3': 'CAN', 'z': 595333.0},
#  {'code3': 'RUS', 'z': 2153756.0},
#  {'code3': 'ISR', 'z': 4209104.0},
#  {'code3': 'USA', 'z': 37459269.0},
#  {'code3': 'BHR', 'z': 214181.0},
#  {'code3': 'MEX', 'z': 609881.0},
#  {'code3': 'CHL', 'z': 1782612.0},
#  {'code3': 'QAT', 'z': 0.0},
#  {'code3': 'CRI', 'z': 53898.0},
#  {'code3': 'ITA', 'z': 2003391.0},
#  {'code3': 'CZE', 'z': 299077.0},
#  {'code3': 'LTU', 'z': 98924.0},
#  {'code3': 'PRT', 'z': 339560.0},
#  {'code3': 'EST', 'z': 52649.0},
#  {'code3': 'AUT', 'z': 272420.0},
#  {'code3': 'HUN', 'z': 398962.0},
#  {'code3': 'CYM', 'z': 10116.0},
#  {'code3': 'SVN', 'z': 83801.0},
#  {'code3': 'FRA', 'z': 2220608.0},
#  {'code3': 'DNK', 'z': 249323.0},
#  {'code3': 'GRC', 'z': 406070.0},
#  {'code3': 'ARG', 'z': 448733.0},
#  {'code3': 'BEL', 'z': 382987.0},
#  {'code3': 'DEU', 'z': 2749786.0},
#  {'code3': 'POL', 'z': 1602745.0},
#  {'code3': 'SWE', 'z': 335031.0},
# ...

# %%
with open('data.json', 'w') as outfile:
    json.dump(totVac, outfile)
